# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.decomposition import KernelPCA
from sklearn.manifold import TSNE
import seaborn as sns
import umap

# %%
pip install umap-learn
# Out:
# Collecting umap-learn
#   Downloading umap_learn-0.5.6-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.5.2)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (0.60.0)
# Collecting pynndescent>=0.5 (from umap-learn)
#   Downloading pynndescent-0.5.13-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from umap-learn) (4.66.5)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn) (0.43.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from pynndescent>=0.5->umap-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->umap-learn) (3.5.0)
# Downloading umap_learn-0.5.6-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 1.7 MB/s eta 0:00:00
# Downloading pynndescent-0.5.13-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 4.5 MB/s eta 0:00:00
# Installing collected packages: pynndescent, umap-learn
# Successfully installed pynndescent-0.5.13 umap-learn-0.5.6

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Data mining/project/Data_with_1_Printing_Gap.csv")

# %%
df_new = df.head(19000)

# %%
# creating list of features
features = ["Rwf", "ECT_Avg","ECT1","ECT2","ECT3","ECT4","ECT5","Speed_Act","Feed_Roll_Gap","GLWeigth(Grammage)","BMWeigth(Grammage)","BLWeigth(Grammage)","CMWeigth(Grammage)","CLWeigth(Grammage)","Finished_Product_Wid","Finished_Product_Leg","Finished_Product_Hig","New_Printing_Gap_1","New_Average_Printing_Gap"]

# %%
#target variable
target = ["BCT_Avg"]

# %%
# Separating out the features
x = df_new.loc[:, features].values

# Separating out the target
y = df_new.loc[:,target].values

# Standardizing the features
x = StandardScaler().fit_transform(x)

# %% [markdown]
# ### Kernel PCA

# %% [markdown]
# ###Kernel = Sigmoid

# %%
kpca = KernelPCA(n_components=2, kernel='sigmoid', gamma=5)
data_kpca = kpca.fit_transform(x)
# Plot the points
plt.figure(figsize=(10, 10))
plt.scatter(data_kpca[:, 0], data_kpca[:, 1], s=5)
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.show()

# %%
kpca = KernelPCA(n_components=2, kernel='sigmoid', gamma=5)
data_kpca_sigmoid = kpca.fit_transform(x)
plt.figure(figsize=(8, 6))

# Scatter plot of the Kernel PCA components, coloring by target variable (BCT_Avg)
sc = plt.scatter(data_kpca_sigmoid[:, 0], data_kpca_sigmoid[:, 1],
                 c=y, cmap='coolwarm', edgecolor='k', s=50)

# Add colorbar to show the range of BCT_Avg values
plt.colorbar(sc, label='BCT_Avg')

# Add labels and title
plt.xlabel('Kernel Principal Component 1')
plt.ylabel('Kernel Principal Component 2')
plt.title('Kernel PCA (Sigmoid Kernel) - First 2 Components with BCT_Avg')

# Show the plot
plt.grid(True)
plt.show()

# %%
# Assuming 'data_kpca' contains the 2D Kernel PCA-transformed data
plt.figure(figsize=(8, 6))

# Scatter plot of the first two kernel principal components
plt.scatter(data_kpca_sigmoid[:, 0], data_kpca_sigmoid[:, 1], c='blue', edgecolor='k', s=50)

# Add labels and title
plt.xlabel('Kernel Principal Component 1')
plt.ylabel('Kernel Principal Component 2')
plt.title('Kernel PCA (Sigmoid Kernel) - First 2 Components')

# Show the plot
plt.grid(True)
plt.show()

# %%
explained_variance = np.var(data_kpca_sigmoid, axis=0)
explained_variance_ratio = explained_variance / np.sum(explained_variance)
print(explained_variance_ratio)
print("This variance is for SIGMOID")
# Out:
# [0.5718121 0.4281879]
# This variance is for SIGMOID

# %% [markdown]
# ###Kernel = rbf

# %%
kpca = KernelPCA(n_components=2, kernel='rbf', gamma=5)
data_kpca_rbf = kpca.fit_transform(x)
plt.figure(figsize=(8, 6))

# Scatter plot of the Kernel PCA components, coloring by target variable (BCT_Avg)
sc = plt.scatter(data_kpca_rbf[:, 0], data_kpca_rbf[:, 1],
                 c=y, cmap='coolwarm', edgecolor='k', s=50)

# Add colorbar to show the range of BCT_Avg values
plt.colorbar(sc, label='BCT_Avg')

# Add labels and title
plt.xlabel('Kernel Principal Component 1')
plt.ylabel('Kernel Principal Component 2')
plt.title('Kernel PCA (RBF Kernel) - First 2 Components with BCT_Avg')

# Show the plot
plt.grid(True)
plt.show()

# %%
# Assuming 'data_kpca' contains the 2D Kernel PCA-transformed data
plt.figure(figsize=(8, 6))

# Scatter plot of the first two kernel principal components
plt.scatter(data_kpca_rbf[:, 0], data_kpca_rbf[:, 1], c='blue', edgecolor='k', s=50)

# Add labels and title
plt.xlabel('Kernel Principal Component 1')
plt.ylabel('Kernel Principal Component 2')
plt.title('Kernel PCA (RBF Kernel) - First 2 Components')

# Show the plot
plt.grid(True)
plt.show()

# %%
explained_variance = np.var(data_kpca_rbf, axis=0)
explained_variance_ratio = explained_variance / np.sum(explained_variance)
print(explained_variance_ratio)
print("This variance is for RBF")
# Out:
# [0.5026503 0.4973497]
# This variance is for RBF

# %% [markdown]
# ###Kernel = poly

# %%
kpca = KernelPCA(n_components=2, kernel='poly', gamma=5)
data_kpca_poly = kpca.fit_transform(x)
plt.figure(figsize=(8, 6))

# Scatter plot of the Kernel PCA components, coloring by target variable (BCT_Avg)
sc = plt.scatter(data_kpca_poly[:, 0], data_kpca_poly[:, 1],
                 c=y, cmap='coolwarm', edgecolor='k', s=50)

# Add colorbar to show the range of BCT_Avg values
plt.colorbar(sc, label='BCT_Avg')

# Add labels and title
plt.xlabel('Kernel Principal Component 1')
plt.ylabel('Kernel Principal Component 2')
plt.title('Kernel PCA (Poly Kernel) - First 2 Components with BCT_Avg')

# Show the plot
plt.grid(True)
plt.show()

# %%
# Assuming 'data_kpca' contains the 2D Kernel PCA-transformed data
plt.figure(figsize=(8, 6))

# Scatter plot of the first two kernel principal components
plt.scatter(data_kpca_poly[:, 0], data_kpca_poly[:, 1], c='blue', edgecolor='k', s=50)

# Add labels and title
plt.xlabel('Kernel Principal Component 1')
plt.ylabel('Kernel Principal Component 2')
plt.title('Kernel PCA (Poly Kernel) - First 2 Components')

# Show the plot
plt.grid(True)
plt.show()

# %%
explained_variance = np.var(data_kpca_poly, axis=0)
explained_variance_ratio = explained_variance / np.sum(explained_variance)
print(explained_variance_ratio)
print("This variance is for poly")
# Out:
# [0.84410681 0.15589319]
# This variance is for poly
